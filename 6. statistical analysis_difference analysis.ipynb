# %% [markdown]
# # Goal:
# 由于健康模型在高胆数据上预测准确率低，需要从数据的角度上描述（健康、高胆换血、高胆未换血）的差异。
# 1. 找到论文里一般用的特征有哪些，做差异分析
# 2. 用这些特征建立机器学习模型，看feature importance，比较哪个特征贡献大。

# %%
import os
import copy
import pylab
import numpy as np
import pandas as pd
import matplotlib
#matplotlib.use("TkAgg")
import matplotlib.pyplot as plt
import mne 
from multiprocessing import Pool
import threading
import pingouin as pg
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
mne.set_log_level('ERROR')

# %%
import matplotlib.font_manager
matplotlib.rcParams['savefig.dpi'] = 300
matplotlib.rcParams["figure.dpi"] = 100
plt.rcParams['font.sans-serif']=['SimHei'] #Show Chinese label
plt.rcParams['axes.unicode_minus']=False   #These two lines need to be set manually
#%matplotlib tk
import inspect
inspect.getfullargspec(mne.io.read_raw_edf)
# Out:
# FullArgSpec(args=['input_fname', 'eog', 'misc', 'stim_channel', 'exclude', 'infer_types', 'include', 'preload', 'units', 'encoding'], varargs=None, varkw=None, defaults=(None, None, 'auto', (), False, None, False, None, 'utf8'), kwonlyargs=['verbose'], kwonlydefaults={'verbose': None}, annotations={})

# %%
def readPath(path):
    file_path = []
    for root, dirs, files in os.walk(path):
        
        for file in files:
            if file.endswith('.edf'):
                path_name = os.path.join(root, file)
                file_path.append(path_name)
            #print(path_name)

    return file_path

# %%
def loadFile(path, exclude_channels=True, 
                             crop_wake_mins=30):
    """Load a raw.edf file.

    Parameters
    ----------
    path : str
        Path to the .edf file containing the raw data. 
    exclude_channels : bool
        If True, only keep EEG channels and discard other modalities 
        (speeds up loading).
    crop_wake_mins : float
        Number of minutes of wake events before and after sleep events.

    Returns
    -------
    mne.io.Raw :
        Raw object containing the EEG and annotations.        
    """

    mapping = {
    # 'EEG Fp1-AV',
    # 'EEG Fp2-AV',
     'EEG C3-AV',
     'EEG C4-AV',
    # 'EEG P3-AV',
     'EEG O1-AV',
     'EEG T3-AV',
     'EEG T4-AV',
     'EEG Cz-AV',
     'EEG Pz-AV',
     'EEG O2-AV',
    # 'EEG P4-AV',
     'ECG',
     'EMG Left_Leg',
     'EMG Right_Leg'}

    
    exclude = mapping if exclude_channels else ()

    #Read the raw data and annotations
    raw = mne.io.read_raw_edf(path, exclude=exclude)

    if not exclude_channels:
        raw.set_channel_types(mapping)

    # Rename EEG channel: replace EEG
    ch_names = {i: i.replace('EEG ', '') 
                for i in raw.ch_names if 'EEG' in i}
    mne.rename_channels(raw.info, ch_names)


    #store the subject information:
    
    basename = os.path.basename(path)
    subj_nb = os.path.splitext(basename)[0] #e.g., 113
    raw.info['subject_info'] = {'id': subj_nb}
    

    return raw

# %%
path_1 = './healthy-2023'
path_2 = './healthy-2024'
path_3 = './hyper-bloodchange-2024'
path_4 = './hyper-blood-change-notchange-sample'

# %%
res_1 = readPath(path_1) #healthy - from 2023
res_4 = readPath(path_4) #高胆红素血症（换血及未换血各3个）

# %%
raws_healthy = [loadFile(f) for f in res_1] #healthy dataset
raws_hyper_6 = [loadFile(f) for f in res_4] #hyper: blood exchanged vs not (6)

# %% [markdown]
# The datasets we have:
# - raws_healthy
# - raws_hyper_26
# - raws_hyper_6

# %% [markdown]
# # Filter

# %%
def filter(raw):
    l_freq, h_freq = None, 30
    raw.load_data().filter(l_freq, h_freq)  # filtering happens in-place

# %%
for raw in raws_healthy:
    filter(raw)

# %%
for raw in raws_hyper_6:
    filter(raw)

# %% [markdown]
# # Extract epochs

# %%
def extract_epochs(raw, chunk_duration=30.):
    """Extract non-overlapping epochs from raw data.
    
    Parameters
    ----------
    raw : mne.io.Raw
        Raw data object to be windowed.
    chunk_duration : float
        Length of a window.
    
    Returns
    -------
    np.ndarray
        Epoched data, of shape (n_epochs, n_channels, n_times).
    np.ndarray
        Event identifiers for each epoch, shape (n_epochs,).
    """
    custom_mapping = {"清醒1": 3, "AS1":2, "QS1":1}
    events, _ = mne.events_from_annotations(
        raw, 
        event_id=custom_mapping, 
        chunk_duration=chunk_duration)


    tmax = 30. - 1. / raw.info['sfreq']  # tmax in included
    picks = mne.pick_types(raw.info, eeg=True)
    epochs = mne.Epochs(raw=raw, events=events, picks=picks, preload=True,
                        event_id=custom_mapping, tmin=0., tmax=tmax, baseline=None)
    
    return epochs

# %% [markdown]
# ### Get epoch lists for datasets with annotations:
# Datasets:
# - raws_healthy
# - raws_hyper_6
#
# Output epochs:
# - epochs_healthy
# - epochs_hyper_6

# %%
#对MyThread进行封装
class MyThread(threading.Thread):
    def __init__(self,func,args,name=''):
        threading.Thread.__init__(self)
        self.func = func
        self.name = name
        self.args = args
        self.res = None
    def run(self):
        self.res = self.func(self.args)
    def getResult(self):
        return self.res

# %%
if __name__ == '__main__' :
    Threads = []
    epochs_healthy = []
    i = 0
    for raw in raws_healthy:
        t = MyThread(func=extract_epochs,args=raw,name ='Thread'+ str(i))
        i+=1
        Threads.append(t)
        t.start()
    for t in Threads:
        t.join()
        epochs_healthy.append(t.getResult()) #epochs_all would be the dataset of all epochs

# %%
if __name__ == '__main__' :
    Threads = []
    epochs_hyper_6 = []
    i = 0
    for raw in raws_hyper_6:
        t = MyThread(func=extract_epochs,args=raw,name ='Thread'+ str(i))
        i+=1
        Threads.append(t)
        t.start()
    for t in Threads:
        t.join()
        epochs_hyper_6.append(t.getResult()) #epochs_all would be the dataset of all epochs

# %% [markdown]
# #### Frequency analysis: Sleep stages x per subject x electrode positions
#
# Based on the 10-20 international system of electrode placement and the electodes we have: <br>
# Our electrodes can be arranged into: <br>
# - Frontal lobe: FP1, FP2 (picks: 0,1)
# - Parietal lobe: C3, Cz, C4, P3, Pz, P4 (picks: 2,10,3,4,11,5)
# - Temporal lobe: T7, T8 (picks: 8,9)
# - Occipital lobe: O1, O2 (picks: 6,7)
#
# Next, we can plot epochs of each sleep stage as an image map: <br>
# 1. each row of pixels in the image representing a single epoch
# 2. the horizontal axis representing time
# 3. each pixel's color representing the signal value at that time sample for that epoch
#
# We saved the image maps.

# %% [markdown]
# ## Power band datasets

# %%
def get_powerbands(epochs,picks,event):
    """
    Parameters
    ------------
    epochs : Epochs
        The data
    picks : Channels
        Channels that uses for analys
    event : sleep stage
        Sleep stage uses for analys

    Returns
    -----------
    subplots
    """
    # specific frequency bands
    FREQ_BANDS = {
        "delta": [0.5, 4.5],# qs
        "theta": [4.5, 8.5],# as
        "alpha": [8.5, 11.5],
        "sigma": [11.5, 15.5],
        "beta": [15.5, 30],
    }
    spectrum = epochs[event].compute_psd(picks=picks,fmin=0.5,fmax=30.0)
    psds,freqs = spectrum.get_data(return_freqs=True)
    # Normalize the PSDs
    psds /= np.sum(psds, axis=-1, keepdims=True)

    power_bands = []
    index = 0
    for fmin, fmax in FREQ_BANDS.values():
        #psds_band = psds[:, :, (freqs >= fmin) & (freqs < fmax)].mean(axis=-1)
        psds_band = np.median(psds[:, :, (freqs >= fmin) & (freqs < fmax)],axis=-1)
        power_bands.append(psds_band.reshape(len(psds), -1))
    return power_bands

# %%
healthy_awake = []
hyper6_awake = []
for i in range(6):
    healthy_awake.append(get_powerbands(epochs_healthy[i],['Fp1-AV','Fp2-AV'],'清醒1'))
    hyper6_awake.append(get_powerbands(epochs_hyper_6[i],['Fp1-AV','Fp2-AV'],'清醒1'))

# %%
healthy_as = []
hyper6_as = []
for i in range(6):
    healthy_as.append(get_powerbands(epochs_healthy[i],['Fp1-AV','Fp2-AV'],'AS1'))
    hyper6_as.append(get_powerbands(epochs_hyper_6[i],['Fp1-AV','Fp2-AV'],'AS1'))

# %%
healthy_qs = []
hyper6_qs = []
for i in range(6):
    healthy_qs.append(get_powerbands(epochs_healthy[i],['Fp1-AV','Fp2-AV'],'QS1'))
    hyper6_qs.append(get_powerbands(epochs_hyper_6[i],['Fp1-AV','Fp2-AV'],'QS1'))

# %%
len(healthy_awake[0][0][3])
# Out:
# 2

# %%
healthy_qs_all = []
for healthy in epochs_healthy:
    healthy_qs_all.append(get_powerbands(healthy,['Fp1-AV','Fp2-AV'],'QS1'))

# %% [markdown]
# ## Combine healthy and hyper datasets as a dataframe

# %%
# waves = ['delta','theta','alpha','sigma','beta']

# def dataframe_powerbands(healthy_powerband, hyper6_powerband, picks_num):
#     """
#     Parameters
#     ----------------
#     healthy_dataset: powerband datasets of all healthy subjects
#     hyper6_dataset: powerband datasets of hyperbilirubin subjects
#     picks_num: the num of pick channel, this can be 0,1, which represented 'Fp1-AV','Fp2-AV'

#     Returns
#     -----------------
#     df: a dataframe includes 
#     status (healthy/换血/未换血), 
#     wave ('delta','theta','alpha','sigma','beta'), 
#     psd values of all epochs - each value is the mean psd of a epoch
#     """
#     status,wave,psd_set = [],[],[]
    
#     for i in range(len(waves)):
#         for j in range (12):
#             if j<6 :
#                 #calculate healthy_powerband
#                 status.append( "健康")
#                 wave.append(waves[i])
#                 psd_set.append(healthy_powerband[j][i][:,picks_num]) #channel selection: 0,1
               
#             elif j>=6 and j<9:
#                 #calculate hyper6_powerband
#                 status.append( "换血")
#                 wave.append(waves[i])
#                 psd_set.append(hyper6_powerband[j-6][i][:,picks_num])
               
#             else:
#                 #calculate hyper6_powerband
#                 status.append( "未换血")
#                 wave.append(waves[i])
#                 psd_set.append(hyper6_powerband[j-6][i][:,picks_num])
                
    
#     df= pd.DataFrame({'status':status,'wave':wave,'psd_set':psd_set})         
#     return df

# %%
# df_awake = dataframe_powerbands(healthy_awake, hyper6_awake, picks_num = 0)

# %%
# df_as = dataframe_powerbands(healthy_as, hyper6_as, picks_num = 0)

# %%
# df_qs = dataframe_powerbands(healthy_qs, hyper6_qs, picks_num = 0)

# %% [markdown]
# ## statistical analysis

# %%
# ranksums(x.iloc[0]['psd_mean'], x.iloc[1]['psd_mean'])

# %%
# for i in range(60):
#     for j in range(60):
#         print(j)
#         print(ranksums(x.iloc[i]['psd_mean'], x.iloc[j]['psd_mean']))

# %%
# #generate a combined dataframe for Awake
# df_awake = dataframe_powerbands(healthy_awake, hyper6_awake, sleep_stage='Awake', picks_num = 0)

# %% [markdown]
# ## ranksum test

# %%
# waves = ['delta','theta','alpha','sigma','beta']
# psd_waves_subject = []
# for i in range(len(waves)):
#     psd_for_waves = []
#     for j in range(len(healthy_awake)):
#         psd_values = healthy_awake[j][i][:, 0] #0 is the channel number
#         psd_for_waves.append(psd_values)
#     #print(psd_for_waves)
#     psd_waves_subject.append(psd_for_waves)
#     #print(ranksums(psd_for_waves[0], psd_for_waves[1]))

# %%
# len(psd_waves_subject[0])

# %%
# for x in range(len(waves)):
#     for y in range(len(healthy_awake)):
#         z = y+1
#         while z < len(healthy_awake):
#             #print(waves[x])
#             #print(y)
#             print(ranksums(psd_waves_subject[x][y],psd_waves_subject[x][z] ))
            
#             z+=1

# %%
from scipy.stats import ranksums
from scipy.stats import mannwhitneyu
waves = ['delta','theta','alpha','sigma','beta']

def get_psd_all(healthy_powerband, hyper6_powerband, picks_num):
    psd = []

    for i in range(len(waves)):
        psd_set = []
        for j in range (12):
            if j<6 :
                #calculate healthy_powerband
                psd_set.append(healthy_powerband[j][i][:,picks_num]) #channel selection: 0,1
               
            elif j>=6 and j<9:
                #calculate hyper6_powerband
                psd_set.append(hyper6_powerband[j-6][i][:,picks_num])
               
            else:
                #calculate hyper6_powerband
                psd_set.append(hyper6_powerband[j-6][i][:,picks_num])    
            
        psd.append(psd_set)
                   
    return psd

# %% [markdown]
# Change the input dataset here.

# %%
psd = get_psd_all(healthy_qs, hyper6_qs, 0)

# %% [markdown]
# ## Perform the Shapiro-Wilk test for normality
#
# The Shapiro-Wilk test tests the null hypothesis that the data was drawn from a normal distribution. <br>

# %%
all_psd = []
for i in range(len(waves)):    
    for j in range(len(psd[0])):
        res = stats.shapiro(psd[i][j])
        all_psd.append(res)

# %%
normal_psd = [] #normally distributed
not_normal_psd = []
for i in range(len(waves)):    
    for j in range(len(psd[0])):
        if stats.shapiro(psd[i][j])[1] > 0.05:
            normal_psd.append(stats.shapiro(psd[i][j]))
        else:
            not_normal_psd.append(stats.shapiro(psd[i][j]))

# %%
len(all_psd),len(normal_psd)
# Out:
# (60, 7)

# %%
normal_psd
# Out:
# [ShapiroResult(statistic=0.9940241033105613, pvalue=0.8896105833311919),
#  ShapiroResult(statistic=0.9769712755715713, pvalue=0.0619713018269692),
#  ShapiroResult(statistic=0.9915160971171525, pvalue=0.20876604266798915),
#  ShapiroResult(statistic=0.994470893029101, pvalue=0.17819294191157747),
#  ShapiroResult(statistic=0.988722411789403, pvalue=0.09544678843849554),
#  ShapiroResult(statistic=0.9921482934484612, pvalue=0.3114243383371289),
#  ShapiroResult(statistic=0.9854906487401484, pvalue=0.22249319511622795)]

# %% [markdown]
# Only 7 out of 60 psds, is normally distributed. Then we cannot use t test, we should choose non parametric test.

# %% [markdown]
# ## Non-parametric test
#
# Perform the Mann-Whitney U rank test on two independent samples. <br>
# The Mann-Whitney U test is a nonparametrix test of the null hypothesis that the distribution underlying sample x is the same as the distribution underlying sample y.

# %%
wave = []
subject_1 = []
subject_2 = []
statistic = []
p_value = []

for i in range(len(waves)):  
    for j in range(len(psd[0])):       
        k = j+1
        while k < len(psd[0]):
            wave.append(waves[i])
            subject_1.append(j+1)
            subject_2.append(k+1)
            # print(waves[i])
            # print(j)
            #print(ranksums(awake_psd[i][j],awake_psd[i][k]))
            statistic.append(mannwhitneyu(psd[i][j],psd[i][k])[0])
            p_value.append(mannwhitneyu(psd[i][j],psd[i][k])[1])
            k+=1

df = pd.DataFrame({'wave':wave, 'subject_1':subject_1, 'subject_2':subject_2, 'statistic':statistic, 'p_value':p_value})
pd.set_option('display.max_rows', None)

# %%
df.loc[df['subject_1'] <=6, 'subject_1_status'] = '健康'
df.loc[(df['subject_1'] >6) & (df['subject_1'] <=9) , 'subject_1_status'] = '换血'
df.loc[df['subject_1'] >9 , 'subject_1_status'] = '未换血'

# %%
df.loc[df['subject_2'] <=6, 'subject_2_status'] = '健康'
df.loc[(df['subject_2'] >6) & (df['subject_2'] <=9) , 'subject_2_status'] = '换血'
df.loc[df['subject_2'] >9 , 'subject_2_status'] = '未换血'

# %%
df
# Out:
#       wave  subject_1  subject_2  statistic        p_value subject_1_status  \
# 0    delta          1          2     5034.0   4.169464e-29               健康
# 1    delta          1          3    16725.0   5.834356e-01               健康
# 2    delta          1          4     4005.0   1.338199e-28               健康
# 3    delta          1          5     3626.0   5.725181e-24               健康
# 4    delta          1          6     7327.0   2.665852e-07               健康
# 5    delta          1          7    40904.0   6.356545e-69               健康
# 6    delta          1          8     6127.0   1.517564e-55               健康
# 7    delta          1          9     7816.0   1.382995e-79               健康
# 8    delta          1         10    11070.0   1.162427e-32               健康
# 9    delta          1         11     3217.0   1.580433e-55               健康
# 10   delta          1         12    10379.0   1.582316e-35               健康
# 11   delta          2          3    12492.0   4.747383e-26               健康
# 12   delta          2          4     6317.0   8.466023e-01               健康
# 13   delta          2          5     5669.0   5.139822e-01               健康
# 14   delta          2          6     7451.0   4.512775e-09               健康
# 15   delta          2          7    42874.0   1.258696e-05               健康
# 16   delta          2          8    10552.0   3.019512e-04               健康
# 17   delta          2          9    14748.0   9.401787e-10               健康
# 18   delta          2         10    14355.0   5.905134e-02               健康
# 19   delta          2         11     6316.0   1.829501e-09               健康
# 20   delta          2         12    12611.0   7.457836e-01               健康
# 21   delta          3          4     1082.0   4.805898e-26               健康
# 22   delta          3          5      977.0   4.129750e-23               健康
# 23   delta          3          6     2555.0   2.512625e-08               健康
# 24   delta          3          7    14573.0   2.070251e-37               健康
# 25   delta          3          8     1568.0   1.960035e-40               健康
# 26   delta          3          9     1818.0   1.490845e-50               健康
# 27   delta          3         10     3415.0   8.202830e-27               健康
# 28   delta          3         11      753.0   9.338990e-41               健康
# 29   delta          3         12     3295.0   8.869812e-28               健康
# 30   delta          4          5     5088.0   3.452464e-01               健康
# 31   delta          4          6     6767.0   2.249678e-10               健康
# 32   delta          4          7    36262.0   5.164431e-06               健康
# 33   delta          4          8     9154.0   3.617906e-04               健康
# 34   delta          4          9    12650.0   1.723957e-09               健康
# 35   delta          4         10    12878.0   2.773443e-02               健康
# 36   delta          4         11     5281.0   7.646779e-10               健康
# 37   delta          4         12    11161.0   8.694814e-01               健康
# 38   delta          5          6     5404.0   1.605940e-07               健康
# 39   delta          5          7    30547.0   3.002583e-05               健康
# 40   delta          5          8     7227.0   6.893849e-05               健康
# 41   delta          5          9    10012.0   8.388337e-10               健康
# 42   delta          5         10     9973.0   3.956289e-01               健康
# 43   delta          5         11     4206.0   5.683445e-10               健康
# 44   delta          5         12     8835.0   3.526898e-01               健康
# 45   delta          6          7    17990.0   4.551618e-16               健康
# 46   delta          6          8     3290.0   1.389338e-18               健康
# 47   delta          6          9     4238.0   7.248973e-26               健康
# 48   delta          6         10     5373.0   2.524659e-07               健康
# 49   delta          6         11     1690.0   1.462398e-23               健康
# 50   delta          6         12     4813.0   1.155098e-09               健康
# 51   delta          7          8   110610.0   4.053096e-01               换血
# 52   delta          7          9   164888.0   1.156016e-02               换血
# 53   delta          7         10   131165.0   1.117137e-13               换血
# 54   delta          7         11    76340.0   9.350207e-02               换血
# 55   delta          7         12   120673.0   1.817594e-06               换血
# 56   delta          8          9    38119.0   5.592273e-03               换血
# 57   delta          8         10    32358.0   4.053096e-10               换血
# 58   delta          8         11    16904.0   5.087045e-03               换血
# 59   delta          8         12    29198.0   2.375924e-04               换血
# 60   delta          9         10    59821.0   2.557055e-21               换血
# 61   delta          9         11    33711.0   8.019362e-01               换血
# 62   delta          9         12    54609.0   2.774215e-11               换血
# 63   delta         10         11     8996.0   1.432323e-18              未换血
# 64   delta         10         12    19577.0   2.179953e-02              未换血
# 65   delta         11         12    25645.0   8.795022e-10              未换血
# 66   theta          1          2     3453.0   7.875364e-37               健康
# 67   theta          1          3    11311.0   2.775059e-06               健康
# 68   theta          1          4     1455.0   1.123540e-42               健康
# 69   theta          1          5     8121.0   6.210243e-07               健康
# 70   theta          1          6     7203.0   1.204049e-07               健康
# 71   theta          1          7    28686.0   3.421135e-88               健康
# 72   theta          1          8     8043.0   6.893311e-48               健康
# 73   theta          1          9     3273.0   1.551816e-95               健康
# 74   theta          1         10     9728.0   2.694817e-37               健康
# 75   theta          1         11     3480.0   3.133555e-54               健康
# 76   theta          1         12    15564.0   6.228497e-20               健康
# 77   theta          2          3    11473.0   7.144269e-18               健康
# 78   theta          2          4     4159.0   4.996355e-06               健康
# 79   theta          2          5     9034.0   5.045584e-17               健康
# 80   theta          2          6     7708.0   8.892542e-11               健康
# 81   theta          2          7    36315.0   1.188996e-10               健康
# 82   theta          2          8    14434.0   4.758991e-01               健康
# 83   theta          2          9    13969.0   2.502024e-11               健康
# 84   theta          2         10    14431.0   4.791712e-02               健康
# 85   theta          2         11     8165.0   4.992758e-04               健康
# 86   theta          2         12    19313.0   3.570195e-14               健康
# 87   theta          3          4      996.0   6.874326e-27               健康
# 88   theta          3          5     4999.0   7.777928e-01               健康
# 89   theta          3          6     4163.0   1.258407e-01               健康
# 90   theta          3          7    16380.0   3.336586e-34               健康
# 91   theta          3          8     5353.0   3.664060e-19               健康
# 92   theta          3          9     2757.0   3.676303e-46               健康
# 93   theta          3         10     6089.0   1.073353e-13               健康
# 94   theta          3         11     2366.0   1.574037e-28               健康
# 95   theta          3         12     9614.0   1.313763e-03               健康
# 96   theta          4          5     8820.0   1.447900e-25               健康
# 97   theta          4          6     7849.0   2.413539e-20               健康
# 98   theta          4          7    42743.0   1.861046e-02               健康
# 99   theta          4          8    16589.0   4.159036e-08               健康
# 100  theta          4          9    18982.0   2.551013e-01               健康
# 101  theta          4         10    16114.0   1.510287e-10               健康
# 102  theta          4         11    10309.0   1.639548e-01               健康
# 103  theta          4         12    19809.0   4.789748e-28               健康
# 104  theta          5          6     3240.0   1.650959e-01               健康
# 105  theta          5          7    12246.0   2.938547e-28               健康
# 106  theta          5          8     3896.0   1.563337e-17               健康
# 107  theta          5          9     1519.0   5.084992e-41               健康
# 108  theta          5         10     4557.0   1.916723e-12               健康
# 109  theta          5         11     1567.0   1.626322e-26               健康
# 110  theta          5         12     7363.0   2.235672e-03               健康
# 111  theta          6          7    13620.0   9.076768e-23               健康
# 112  theta          6          8     4972.0   1.550046e-10               健康
# 113  theta          6          9     2924.0   1.441427e-31               健康
# 114  theta          6         10     5375.0   2.566057e-07               健康
# 115  theta          6         11     2259.0   2.309511e-19               健康
# 116  theta          6         12     8229.0   3.564373e-01               健康
# 117  theta          7          8   146155.0   5.936881e-18               换血
# 118  theta          7          9   187147.0   3.181989e-01               换血
# 119  theta          7         10   140093.0   2.586074e-21               换血
# 120  theta          7         11    98127.0   1.077008e-04               换血
# 121  theta          7         12   162087.0   5.311556e-46               换血
# 122  theta          8          9    25151.0   6.875447e-19               换血
# 123  theta          8         10    26084.0   1.264939e-01               换血
# 124  theta          8         11    14714.0   2.929855e-06               换血
# 125  theta          8         12    34874.0   2.390989e-15               换血
# 126  theta          9         10    60650.0   4.558728e-23               换血
# 127  theta          9         11    39787.0   1.693558e-03               换血
# 128  theta          9         12    73704.0   3.763572e-58               换血
# 129  theta         10         11    12315.0   7.540908e-09              未换血
# 130  theta         10         12    30117.0   1.364763e-09              未换血
# 131  theta         11         12    31407.0   9.468174e-30              未换血
# 132  alpha          1          2    12359.0   1.404606e-05               健康
# 133  alpha          1          3     9361.0   4.939664e-11               健康
# 134  alpha          1          4     5444.0   6.096304e-22               健康
# 135  alpha          1          5    10668.0   3.679884e-02               健康
# 136  alpha          1          6     3627.0   1.447987e-21               健康
# 137  alpha          1          7    53308.0   7.835305e-52               健康
# 138  alpha          1          8    15162.0   1.541492e-24               健康
# 139  alpha          1          9    12858.0   1.286895e-63               健康
# 140  alpha          1         10    31830.0   1.617090e-01               健康
# 141  alpha          1         11    13169.0   2.215430e-17               健康
# 142  alpha          1         12    41761.0   5.019306e-14               健康
# 143  alpha          2          3     6458.0   3.411654e-01               健康
# 144  alpha          2          4     4652.0   3.621052e-04               健康
# 145  alpha          2          5     6272.0   4.151186e-02               健康
# 146  alpha          2          6     3079.0   2.752546e-06               健康
# 147  alpha          2          7    35157.0   9.977859e-12               健康
# 148  alpha          2          8    10846.0   1.016681e-03               健康
# 149  alpha          2          9    12904.0   1.080713e-13               健康
# 150  alpha          2         10    16765.0   2.024025e-06               健康
# 151  alpha          2         11     9043.0   2.265284e-02               健康
# 152  alpha          2         12    20041.0   3.339873e-17               健康
# 153  alpha          3          4     4393.0   3.396982e-04               健康
# 154  alpha          3          5     6685.0   1.786235e-04               健康
# 155  alpha          3          6     2717.0   2.401697e-07               健康
# 156  alpha          3          7    29870.0   5.846987e-15               健康
# 157  alpha          3          8    10423.0   1.943606e-03               健康
# 158  alpha          3          9    11024.0   2.459245e-16               健康
# 159  alpha          3         10    17511.0   3.747189e-11               健康
# 160  alpha          3         11     8776.0   4.689121e-02               健康
# 161  alpha          3         12    20888.0   5.467553e-26               健康
# 162  alpha          4          5     7372.0   1.357751e-11               健康
# 163  alpha          4          6     3427.0   9.242733e-03               健康
# 164  alpha          4          7    33596.0   4.630811e-08               健康
# 165  alpha          4          8    12406.0   6.954963e-01               健康
# 166  alpha          4          9    14742.0   1.041673e-05               健康
# 167  alpha          4         10    18286.0   2.820043e-20               健康
# 168  alpha          4         11    10323.0   1.576844e-01               健康
# 169  alpha          4         12    20713.0   6.124136e-34               健康
# 170  alpha          5          6     1354.0   7.641611e-13               健康
# 171  alpha          5          7    18578.0   4.995181e-18               健康
# 172  alpha          5          8     5598.0   5.597527e-10               健康
# 173  alpha          5          9     4869.0   5.466649e-26               健康
# 174  alpha          5         10    11257.0   6.522437e-03               健康
# 175  alpha          5         11     4866.0   3.692420e-07               健康
# 176  alpha          5         12    14400.0   1.137488e-12               健康
# 177  alpha          6          7    35020.0   1.329645e-01               健康
# 178  alpha          6          8    11541.0   3.044862e-03               健康
# 179  alpha          6          9    15570.0   6.888773e-01               健康
# 180  alpha          6         10    14839.0   1.874158e-20               健康
# 181  alpha          6         11     9535.0   1.077285e-04               健康
# 182  alpha          6         12    16374.0   4.710491e-30               健康
# 183  alpha          7          8   137191.0   2.623378e-11               换血
# 184  alpha          7          9   199364.0   3.366490e-03               换血
# 185  alpha          7         10   159226.0   8.891094e-44               换血
# 186  alpha          7         11   112965.0   1.972888e-14               换血
# 187  alpha          7         12   171795.0   7.474460e-61               换血
# 188  alpha          8          9    32301.0   3.583416e-08               换血
# 189  alpha          8         10    37145.0   6.440788e-23               换血
# 190  alpha          8         11    21644.0   2.097771e-01               换血
# 191  alpha          8         12    42435.0   5.832752e-42               换血
# 192  alpha          9         10    71633.0   3.973673e-53               换血
# 193  alpha          9         11    45957.0   4.627787e-11               换血
# 194  alpha          9         12    78326.0   2.981306e-75               换血
# 195  alpha         10         11     9518.0   8.763713e-17              未换血
# 196  alpha         10         12    28982.0   2.470060e-07              未换血
# 197  alpha         11         12    32085.0   7.291855e-33              未换血
# 198  sigma          1          2    12977.0   1.666803e-04               健康
# 199  sigma          1          3     6168.0   4.421832e-22               健康
# 200  sigma          1          4     7420.0   2.649586e-14               健康
# 201  sigma          1          5     9191.0   1.647549e-04               健康
# 202  sigma          1          6     2095.0   6.807245e-30               健康
# 203  sigma          1          7    46396.0   4.758085e-61               健康
# 204  sigma          1          8    14232.0   3.921676e-27               健康
# 205  sigma          1          9    13509.0   1.092687e-61               健康
# 206  sigma          1         10    23911.0   2.388515e-04               健康
# 207  sigma          1         11    11492.0   3.082364e-22               健康
# 208  sigma          1         12    44700.0   5.360713e-21               健康
# 209  sigma          2          3     4962.0   1.414879e-04               健康
# 210  sigma          2          4     5353.0   3.185373e-02               健康
# 211  sigma          2          5     5627.0   5.781213e-01               健康
# 212  sigma          2          6     2181.0   7.058507e-12               健康
# 213  sigma          2          7    32556.0   2.363927e-14               健康
# 214  sigma          2          8    10478.0   2.189235e-04               健康
# 215  sigma          2          9    12655.0   2.789657e-14               健康
# 216  sigma          2         10    13632.0   3.035497e-01               健康
# 217  sigma          2         11     8036.0   2.544545e-04               健康
# 218  sigma          2         12    20424.0   6.360610e-19               健康
# 219  sigma          3          4     7189.0   2.129761e-02               健康
# 220  sigma          3          5     7398.0   4.963522e-08               健康
# 221  sigma          3          6     2565.0   2.901826e-08               健康
# 222  sigma          3          7    34919.0   7.037472e-10               健康
# 223  sigma          3          8    13720.0   4.820422e-01               健康
# 224  sigma          3          9    15726.0   2.066731e-06               健康
# 225  sigma          3         10    16996.0   2.225784e-09               健康
# 226  sigma          3         11    10153.0   9.728426e-01               健康
# 227  sigma          3         12    22721.0   2.125353e-37               健康
# 228  sigma          4          5     6112.0   3.815999e-04               健康
# 229  sigma          4          6     1783.0   2.422378e-12               健康
# 230  sigma          4          7    27490.0   4.624107e-14               健康
# 231  sigma          4          8    10509.0   5.525565e-02               健康
# 232  sigma          4          9    11512.0   5.214168e-12               健康
# 233  sigma          4         10    14122.0   1.351494e-04               健康
# 234  sigma          4         11     7798.0   1.755623e-02               健康
# 235  sigma          4         12    20290.0   4.144583e-31               健康
# 236  sigma          5          6      940.0   3.282103e-17               健康
# 237  sigma          5          7    17771.0   3.380281e-19               健康
# 238  sigma          5          8     6202.0   7.544385e-08               健康
# 239  sigma          5          9     6187.0   4.773872e-21               健康
# 240  sigma          5         10     9572.0   7.908700e-01               健康
# 241  sigma          5         11     4772.0   1.580361e-07               健康
# 242  sigma          5         12    15919.0   1.298947e-20               健康
# 243  sigma          6          7    41019.0   4.069907e-01               健康
# 244  sigma          6          8    14185.0   1.667287e-11               健康
# 245  sigma          6          9    18675.0   1.776002e-02               健康
# 246  sigma          6         10    14834.0   2.012885e-20               健康
# 247  sigma          6         11    10676.0   3.838687e-09               健康
# 248  sigma          6         12    17052.0   2.177912e-35               健康
# 249  sigma          7          8   147999.0   1.588550e-19               换血
# 250  sigma          7          9   194987.0   2.514002e-02               换血
# 251  sigma          7         10   152886.0   2.073037e-35               换血
# 252  sigma          7         11   112329.0   6.868059e-14               换血
# 253  sigma          7         12   178061.0   1.433840e-71               换血
# 254  sigma          8          9    29774.0   2.082694e-11               换血
# 255  sigma          8         10    32385.0   3.557572e-10               换血
# 256  sigma          8         11    19327.0   4.666993e-01               换血
# 257  sigma          8         12    43953.0   5.773448e-49               换血
# 258  sigma          9         10    64580.0   2.377557e-32               换血
# 259  sigma          9         11    43554.0   1.593140e-07               换血
# 260  sigma          9         12    78283.0   4.404252e-75               换血
# 261  sigma         10         11    12025.0   1.522384e-09              未换血
# 262  sigma         10         12    35412.0   1.106386e-24              未换血
# 263  sigma         11         12    33507.0   6.433947e-40              未换血
# 264   beta          1          2     6378.0   2.780487e-23               健康
# 265   beta          1          3     2072.0   2.951626e-42               健康
# 266   beta          1          4     3913.0   4.670114e-29               健康
# 267   beta          1          5     4525.0   1.146118e-19               健康
# 268   beta          1          6      508.0   5.039623e-40               健康
# 269   beta          1          7    13588.0  2.415551e-115               健康
# 270   beta          1          8    11094.0   6.744604e-37               健康
# 271   beta          1          9     1589.0  7.984956e-102               健康
# 272   beta          1         10    13722.0   1.936514e-24               健康
# 273   beta          1         11     4629.0   9.530825e-49               健康
# 274   beta          1         12    26363.0   2.335537e-02               健康
# 275   beta          2          3     8481.0   3.670286e-03               健康
# 276   beta          2          4     8299.0   1.337339e-04               健康
# 277   beta          2          5     7143.0   5.345287e-05               健康
# 278   beta          2          6     3651.0   9.412586e-04               健康
# 279   beta          2          7    44529.0   1.210684e-04               健康
# 280   beta          2          8    17486.0   3.867101e-05               健康
# 281   beta          2          9    16173.0   3.293400e-07               健康
# 282   beta          2         10    17206.0   1.327992e-07               健康
# 283   beta          2         11    12564.0   1.110641e-02               健康
# 284   beta          2         12    20217.0   5.547421e-18               健康
# 285   beta          3          4     7890.0   1.575758e-04               健康
# 286   beta          3          5     6676.0   1.945797e-04               健康
# 287   beta          3          6     1928.0   8.782818e-13               健康
# 288   beta          3          7    20873.0   7.118452e-27               健康
# 289   beta          3          8    15366.0   9.279428e-03               健康
# 290   beta          3          9     6567.0   1.911389e-30               健康
# 291   beta          3         10    15977.0   2.275638e-06               健康
# 292   beta          3         11     9892.0   6.860179e-01               健康
# 293   beta          3         12    21370.0   8.838513e-29               健康
# 294   beta          4          5     5072.0   3.664783e-01               健康
# 295   beta          4          6     1245.0   2.933502e-17               健康
# 296   beta          4          7    15885.0   1.481390e-30               健康
# 297   beta          4          8    11484.0   4.654783e-01               健康
# 298   beta          4          9     4544.0   1.249184e-34               健康
# 299   beta          4         10    12179.0   1.959847e-01               健康
# 300   beta          4         11     6766.0   8.724925e-05               健康
# 301   beta          4         12    17738.0   9.523130e-17               健康
# 302   beta          5          6     1092.0   1.583083e-15               健康
# 303   beta          5          7    12883.0   4.042668e-27               健康
# 304   beta          5          8     9149.0   1.741739e-01               健康
# 305   beta          5          9     3700.0   7.868613e-31               健康
# 306   beta          5         10     9700.0   6.514980e-01               健康
# 307   beta          5         11     5506.0   6.250504e-05               健康
# 308   beta          5         12    14023.0   5.104899e-11               健康
# 309   beta          6          7    41419.0   3.247713e-01               健康
# 310   beta          6          8    15395.0   2.730521e-17               健康
# 311   beta          6          9    15874.0   8.973607e-01               健康
# 312   beta          6         10    14974.0   2.667055e-21               健康
# 313   beta          6         11    11275.0   3.635534e-12               健康
# 314   beta          6         12    16842.0   1.093776e-33               健康
# 315   beta          7          8   171619.0   6.623328e-46               换血
# 316   beta          7          9   159609.0   7.767095e-04               换血
# 317   beta          7         10   166425.0   2.163548e-54               换血
# 318   beta          7         11   126496.0   1.264773e-28               换血
# 319   beta          7         12   185498.0   1.923669e-85               换血
# 320   beta          8          9    13447.0   6.169280e-47               换血
# 321   beta          8         10    27114.0   2.124540e-02               换血
# 322   beta          8         11    16542.0   1.862845e-03               换血
# 323   beta          8         12    37095.0   9.723928e-22               换血
# 324   beta          9         10    72169.0   6.362827e-55               换血
# 325   beta          9         11    55480.0   1.230830e-32               换血
# 326   beta          9         12    79481.0   7.072977e-80               换血
# 327   beta         10         11    12877.0   1.381865e-07              未换血
# 328   beta         10         12    31758.0   1.835372e-13              未换血
# 329   beta         11         12    32029.0   1.336930e-32              未换血
#
#     subject_2_status
# 0                 健康
# 1                 健康
# 2                 健康
# 3                 健康
# 4                 健康
# 5                 换血
# 6                 换血
# 7                 换血
# 8                未换血
# 9                未换血
# 10               未换血
# 11                健康
# 12                健康
# 13                健康
# 14                健康
# 15                换血
# 16                换血
# 17                换血
# 18               未换血
# 19               未换血
# 20               未换血
# 21                健康
# 22                健康
# 23                健康
# 24                换血
# 25                换血
# 26                换血
# 27               未换血
# 28               未换血
# 29               未换血
# 30                健康
# 31                健康
# 32                换血
# 33                换血
# 34                换血
# 35               未换血
# 36               未换血
# 37               未换血
# 38                健康
# 39                换血
# 40                换血
# 41                换血
# 42               未换血
# 43               未换血
# 44               未换血
# 45                换血
# 46                换血
# 47                换血
# 48               未换血
# 49               未换血
# 50               未换血
# 51                换血
# 52                换血
# 53               未换血
# 54               未换血
# 55               未换血
# 56                换血
# 57               未换血
# 58               未换血
# 59               未换血
# 60               未换血
# 61               未换血
# 62               未换血
# 63               未换血
# 64               未换血
# 65               未换血
# 66                健康
# 67                健康
# 68                健康
# 69                健康
# 70                健康
# 71                换血
# 72                换血
# 73                换血
# 74               未换血
# 75               未换血
# 76               未换血
# 77                健康
# 78                健康
# 79                健康
# 80                健康
# 81                换血
# 82                换血
# 83                换血
# 84               未换血
# 85               未换血
# 86               未换血
# 87                健康
# 88                健康
# 89                健康
# 90                换血
# 91                换血
# 92                换血
# 93               未换血
# 94               未换血
# 95               未换血
# 96                健康
# 97                健康
# 98                换血
# 99                换血
# 100               换血
# 101              未换血
# 102              未换血
# 103              未换血
# 104               健康
# 105               换血
# 106               换血
# 107               换血
# 108              未换血
# 109              未换血
# 110              未换血
# 111               换血
# 112               换血
# 113               换血
# 114              未换血
# 115              未换血
# 116              未换血
# 117               换血
# 118               换血
# 119              未换血
# 120              未换血
# 121              未换血
# 122               换血
# 123              未换血
# 124              未换血
# 125              未换血
# 126              未换血
# 127              未换血
# 128              未换血
# 129              未换血
# 130              未换血
# 131              未换血
# 132               健康
# 133               健康
# 134               健康
# 135               健康
# 136               健康
# 137               换血
# 138               换血
# 139               换血
# 140              未换血
# 141              未换血
# 142              未换血
# 143               健康
# 144               健康
# 145               健康
# 146               健康
# 147               换血
# 148               换血
# 149               换血
# 150              未换血
# 151              未换血
# 152              未换血
# 153               健康
# 154               健康
# 155               健康
# 156               换血
# 157               换血
# 158               换血
# 159              未换血
# 160              未换血
# 161              未换血
# 162               健康
# 163               健康
# 164               换血
# 165               换血
# 166               换血
# 167              未换血
# 168              未换血
# 169              未换血
# 170               健康
# 171               换血
# 172               换血
# 173               换血
# 174              未换血
# 175              未换血
# 176              未换血
# 177               换血
# 178               换血
# 179               换血
# 180              未换血
# 181              未换血
# 182              未换血
# 183               换血
# 184               换血
# 185              未换血
# 186              未换血
# 187              未换血
# 188               换血
# 189              未换血
# 190              未换血
# 191              未换血
# 192              未换血
# 193              未换血
# 194              未换血
# 195              未换血
# 196              未换血
# 197              未换血
# 198               健康
# 199               健康
# 200               健康
# 201               健康
# 202               健康
# 203               换血
# 204               换血
# 205               换血
# 206              未换血
# 207              未换血
# 208              未换血
# 209               健康
# 210               健康
# 211               健康
# 212               健康
# 213               换血
# 214               换血
# 215               换血
# 216              未换血
# 217              未换血
# 218              未换血
# 219               健康
# 220               健康
# 221               健康
# 222               换血
# 223               换血
# 224               换血
# 225              未换血
# 226              未换血
# 227              未换血
# 228               健康
# 229               健康
# 230               换血
# 231               换血
# 232               换血
# 233              未换血
# 234              未换血
# 235              未换血
# 236               健康
# 237               换血
# 238               换血
# 239               换血
# 240              未换血
# 241              未换血
# 242              未换血
# 243               换血
# 244               换血
# 245               换血
# 246              未换血
# 247              未换血
# 248              未换血
# 249               换血
# 250               换血
# 251              未换血
# 252              未换血
# 253              未换血
# 254               换血
# 255              未换血
# 256              未换血
# 257              未换血
# 258              未换血
# 259              未换血
# 260              未换血
# 261              未换血
# 262              未换血
# 263              未换血
# 264               健康
# 265               健康
# 266               健康
# 267               健康
# 268               健康
# 269               换血
# 270               换血
# 271               换血
# 272              未换血
# 273              未换血
# 274              未换血
# 275               健康
# 276               健康
# 277               健康
# 278               健康
# 279               换血
# 280               换血
# 281               换血
# 282              未换血
# 283              未换血
# 284              未换血
# 285               健康
# 286               健康
# 287               健康
# 288               换血
# 289               换血
# 290               换血
# 291              未换血
# 292              未换血
# 293              未换血
# 294               健康
# 295               健康
# 296               换血
# 297               换血
# 298               换血
# 299              未换血
# 300              未换血
# 301              未换血
# 302               健康
# 303               换血
# 304               换血
# 305               换血
# 306              未换血
# 307              未换血
# 308              未换血
# 309               换血
# 310               换血
# 311               换血
# 312              未换血
# 313              未换血
# 314              未换血
# 315               换血
# 316               换血
# 317              未换血
# 318              未换血
# 319              未换血
# 320               换血
# 321              未换血
# 322              未换血
# 323              未换血
# 324              未换血
# 325              未换血
# 326              未换血
# 327              未换血
# 328              未换血
# 329              未换血

# %% [markdown]
# ### Different distribution: reject the null hypothesis of same distribution

# %%
diff_df = df[df['p_value']>0.05]
diff_df
# Out:
#       wave  subject_1  subject_2  statistic   p_value subject_1_status  \
# 1    delta          1          3    16725.0  0.583436               健康
# 12   delta          2          4     6317.0  0.846602               健康
# 13   delta          2          5     5669.0  0.513982               健康
# 18   delta          2         10    14355.0  0.059051               健康
# 20   delta          2         12    12611.0  0.745784               健康
# 30   delta          4          5     5088.0  0.345246               健康
# 37   delta          4         12    11161.0  0.869481               健康
# 42   delta          5         10     9973.0  0.395629               健康
# 44   delta          5         12     8835.0  0.352690               健康
# 51   delta          7          8   110610.0  0.405310               换血
# 54   delta          7         11    76340.0  0.093502               换血
# 61   delta          9         11    33711.0  0.801936               换血
# 82   theta          2          8    14434.0  0.475899               健康
# 88   theta          3          5     4999.0  0.777793               健康
# 89   theta          3          6     4163.0  0.125841               健康
# 100  theta          4          9    18982.0  0.255101               健康
# 102  theta          4         11    10309.0  0.163955               健康
# 104  theta          5          6     3240.0  0.165096               健康
# 116  theta          6         12     8229.0  0.356437               健康
# 118  theta          7          9   187147.0  0.318199               换血
# 123  theta          8         10    26084.0  0.126494               换血
# 140  alpha          1         10    31830.0  0.161709               健康
# 143  alpha          2          3     6458.0  0.341165               健康
# 165  alpha          4          8    12406.0  0.695496               健康
# 168  alpha          4         11    10323.0  0.157684               健康
# 177  alpha          6          7    35020.0  0.132965               健康
# 179  alpha          6          9    15570.0  0.688877               健康
# 190  alpha          8         11    21644.0  0.209777               换血
# 211  sigma          2          5     5627.0  0.578121               健康
# 216  sigma          2         10    13632.0  0.303550               健康
# 223  sigma          3          8    13720.0  0.482042               健康
# 226  sigma          3         11    10153.0  0.972843               健康
# 231  sigma          4          8    10509.0  0.055256               健康
# 240  sigma          5         10     9572.0  0.790870               健康
# 243  sigma          6          7    41019.0  0.406991               健康
# 256  sigma          8         11    19327.0  0.466699               换血
# 292   beta          3         11     9892.0  0.686018               健康
# 294   beta          4          5     5072.0  0.366478               健康
# 297   beta          4          8    11484.0  0.465478               健康
# 299   beta          4         10    12179.0  0.195985               健康
# 304   beta          5          8     9149.0  0.174174               健康
# 306   beta          5         10     9700.0  0.651498               健康
# 309   beta          6          7    41419.0  0.324771               健康
# 311   beta          6          9    15874.0  0.897361               健康
#
#     subject_2_status
# 1                 健康
# 12                健康
# 13                健康
# 18               未换血
# 20               未换血
# 30                健康
# 37               未换血
# 42               未换血
# 44               未换血
# 51                换血
# 54               未换血
# 61               未换血
# 82                换血
# 88                健康
# 89                健康
# 100               换血
# 102              未换血
# 104               健康
# 116              未换血
# 118               换血
# 123              未换血
# 140              未换血
# 143               健康
# 165               换血
# 168              未换血
# 177               换血
# 179               换血
# 190              未换血
# 211               健康
# 216              未换血
# 223               换血
# 226              未换血
# 231               换血
# 240              未换血
# 243               换血
# 256              未换血
# 292              未换血
# 294               健康
# 297               换血
# 299              未换血
# 304               换血
# 306              未换血
# 309               换血
# 311               换血

# %%
print('The number of all tested subjects is: '+ str(len(df)))
print('The number of all statistically different subjects is: '+ str(len(diff_df)))
print('the different ratio is: '+str(round(len(diff_df)/len(df),2)))
# Out:
# The number of all tested subjects is: 330
# The number of all statistically different subjects is: 286
# the different ratio is: 0.87

# %%
330/5
# Out:
# 66.0

# %% [markdown]
# ### 分波段分析

# %% [markdown]
# ### 比例统计：
# - 健康 VS 健康
# - 健康 VS 换血
# - 健康 VS 未换血
# - 换血 VS 未换血

# %%
#('delta','theta','alpha','sigma','beta')
selected_wave = 'beta'
diff_df = df[df['p_value']>0.05]

diff_df = diff_df[diff_df['wave'] == selected_wave]

diff_df[['wave','subject_1_status', 'subject_2_status']] = np.sort(diff_df[['wave', 'subject_1_status', 'subject_2_status']], axis=1)
#diff_df.groupby(['subject_1_status', 'subject_2_status']).statistic.agg('count').reset_index().values.tolist()

diff_count = diff_df.groupby(['subject_1_status', 'subject_2_status']).statistic.agg('count').reset_index()
diff_count.insert(loc=3,column='ratio', value=round(diff_count['statistic']/diff_count['statistic'].sum(),2))
diff_count.insert(loc=2, column='pair', value =diff_count['subject_1_status'] + ' VS ' + diff_count['subject_2_status'] )


diff_count = diff_count.style.set_caption('Count of different datasets in QS, beta')
diff_count
# Out:
# <style type="text/css">
# </style>
# <table id="T_c964a">
#   <caption>Count of different datasets in QS, beta</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c964a_level0_col0" class="col_heading level0 col0" >subject_1_status</th>
#       <th id="T_c964a_level0_col1" class="col_heading level0 col1" >subject_2_status</th>
#       <th id="T_c964a_level0_col2" class="col_heading level0 col2" >pair</th>
#       <th id="T_c964a_level0_col3" class="col_heading level0 col3" >statistic</th>
#       <th id="T_c964a_level0_col4" class="col_heading level0 col4" >ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c964a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c964a_row0_col0" class="data row0 col0" >健康</td>
#       <td id="T_c964a_row0_col1" class="data row0 col1" >健康</td>
#       <td id="T_c964a_row0_col2" class="data row0 col2" >健康 VS 健康</td>
#       <td id="T_c964a_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_c964a_row0_col4" class="data row0 col4" >0.120000</td>
#     </tr>
#     <tr>
#       <th id="T_c964a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c964a_row1_col0" class="data row1 col0" >健康</td>
#       <td id="T_c964a_row1_col1" class="data row1 col1" >换血</td>
#       <td id="T_c964a_row1_col2" class="data row1 col2" >健康 VS 换血</td>
#       <td id="T_c964a_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_c964a_row1_col4" class="data row1 col4" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_c964a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c964a_row2_col0" class="data row2 col0" >健康</td>
#       <td id="T_c964a_row2_col1" class="data row2 col1" >未换血</td>
#       <td id="T_c964a_row2_col2" class="data row2 col2" >健康 VS 未换血</td>
#       <td id="T_c964a_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_c964a_row2_col4" class="data row2 col4" >0.380000</td>
#     </tr>
#   </tbody>
# </table>

# %%
len(diff_df)
# Out:
# 44

# %%
diff_df
# Out:
#      wave  subject_1  subject_2  statistic   p_value subject_1_status  \
# 292  beta          3         11     9892.0  0.686018               健康
# 294  beta          4          5     5072.0  0.366478               健康
# 297  beta          4          8    11484.0  0.465478               健康
# 299  beta          4         10    12179.0  0.195985               健康
# 304  beta          5          8     9149.0  0.174174               健康
# 306  beta          5         10     9700.0  0.651498               健康
# 309  beta          6          7    41419.0  0.324771               健康
# 311  beta          6          9    15874.0  0.897361               健康
#
#     subject_2_status
# 292              未换血
# 294               健康
# 297               换血
# 299              未换血
# 304               换血
# 306              未换血
# 309               换血
# 311               换血

# %%
# fig, ax = plt.subplots()
# ax.pie(diff_count['ratio'],labels = diff_count['pair'], autopct='%1.1f%%')
# #ax.pie(diff_count['statistic'],labels = diff_count['pair'])
# ax.set_title('AS delta')
